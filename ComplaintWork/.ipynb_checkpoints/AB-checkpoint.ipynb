# %%
# !pip install yake pandarallel pandas matplotlib tqdm seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yake in /home/stephan/.local/lib/python3.10/site-packages (0.4.8)
# Requirement already satisfied: pandarallel in /home/stephan/.local/lib/python3.10/site-packages (1.6.4)
# Requirement already satisfied: pandas in /home/stephan/.local/lib/python3.10/site-packages (1.5.2)
# Requirement already satisfied: matplotlib in /home/stephan/.local/lib/python3.10/site-packages (3.6.2)
# Requirement already satisfied: tqdm in /home/stephan/.local/lib/python3.10/site-packages (4.64.1)
# Requirement already satisfied: seaborn in /home/stephan/.local/lib/python3.10/site-packages (0.12.2)
# Requirement already satisfied: networkx in /home/stephan/.local/lib/python3.10/site-packages (from yake) (3.0)
# Requirement already satisfied: tabulate in /home/stephan/.local/lib/python3.10/site-packages (from yake) (0.9.0)
# Requirement already satisfied: numpy in /home/stephan/.local/lib/python3.10/site-packages (from yake) (1.23.5)
# Requirement already satisfied: jellyfish in /home/stephan/.local/lib/python3.10/site-packages (from yake) (0.11.2)
# Requirement already satisfied: click>=6.0 in /home/stephan/.local/lib/python3.10/site-packages (from yake) (8.1.3)
# Requirement already satisfied: segtok in /home/stephan/.local/lib/python3.10/site-packages (from yake) (1.5.11)
# Requirement already satisfied: dill>=0.3.1 in /home/stephan/.local/lib/python3.10/site-packages (from pandarallel) (0.3.6)
# Requirement already satisfied: psutil in /usr/lib/python3.10/site-packages (from pandarallel) (5.9.4)
# Requirement already satisfied: pytz>=2020.1 in /home/stephan/.local/lib/python3.10/site-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/stephan/.local/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in /home/stephan/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: regex in /home/stephan/.local/lib/python3.10/site-packages (from segtok->yake) (2022.10.31)

# %%
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.8.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 324.8 kB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: matplotlib in /home/stephan/.local/lib/python3.10/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: pillow in /usr/lib/python3.10/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: numpy>=1.6.1 in /home/stephan/.local/lib/python3.10/site-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/stephan/.local/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/stephan/.local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
# Check KEYBERT
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import pickle
from nltk.tokenize import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from spellchecker import SpellChecker
from nltk.stem import WordNetLemmatizer
import re
import gc
import swifter
import yake
import wordcloud
from wordcloud import WordCloud, STOPWORDS
from pandarallel import pandarallel # works bad on windows
#from multi_rake import Rake


# Setup tqdm and parallel
tqdm.pandas()
pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 2 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %% [markdown]
# Task A (cleaning) + Task B

# %%
complaints = pd.read_csv("./data/train.csv")

# %%
complaints.head(10)
# Out:
#    Unnamed: 0           product  \
# 0           0       credit_card
# 1           1       credit_card
# 2           2    retail_banking
# 3           3  credit_reporting
# 4           4  credit_reporting
# 5           5  credit_reporting
# 6           6  credit_reporting
# 7           7  credit_reporting
# 8           8  credit_reporting
# 9           9  credit_reporting
#
#                                            narrative
# 0  purchase order day shipping amount receive pro...
# 1  forwarded message date tue subject please inve...
# 2  forwarded message cc sent friday pdt subject f...
# 3  payment history missing credit report speciali...
# 4  payment history missing credit report made mis...
# 5  payment history missing credit report made mis...
# 6  va date complaint experian credit bureau invol...
# 7  account reported abbreviated name full name se...
# 8  account reported abbreviated name full name se...
# 9  usdoexxxx account reported abbreviated name fu...

# %% [markdown]
# Clear dataset from unneeded columns

# %%
complaints = complaints.drop(["Date received", "Sub-product", "Issue", "Sub-issue", "Company public response", "Company", "State", "ZIP code", "Tags", "Consumer consent provided?", "Submitted via", "Date sent to company", "Company response to consumer", "Timely response?", "Consumer disputed?"], axis=1)

# %%
# Rename columns to convinient
complaints = complaints.rename(columns={"Consumer complaint narrative": "narrative"})

# %%
# Drop nan
complaints = complaints.dropna()
complaints.isna().sum()
# Out:
# Product         0
# narrative       0
# Complaint ID    0
# dtype: int64

# %%
complaints.Product = pd.Categorical(complaints.Product)
complaints['class'] = complaints.Product.cat.codes

# %%
complaints.head(5)
# Out:
#                                               Product
# 2                                            Mortgage  \
# 9   Credit reporting, credit repair services, or o...
# 13  Credit reporting, credit repair services, or o...
# 15  Credit reporting, credit repair services, or o...
# 24                                    Debt collection
#
#                                             narrative  Complaint ID  class
# 2   This complaint/letter serves as an appeal of t...       4729864     10
# 9   Accounts added and/or created unbeknownst to m...       4065272      6
# 13  I had a ccj which was paid within a month of t...       4034581      6
# 15  After sending multiple disputes to Equifax, Th...       4023957      6
# 24  XXXX direct marketing is a very old debt that ...       3909146      7

# %%
# Columns description table
# Product - Target class name (not used for training)
# narrative - Original text of complaint
# Complaint id - id of complaint (will be usefull for final mapping, this is not a feature)
# class - mapping of Prduct to categorial feature (use for training)

# %%
# Get class distribution (and verify that class to complaint id mapping correct)
complaints.groupby('Product').count().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
# !mkdir processed
# Out:
# Џ®¤Ї ЇЄ  Ё«Ё д ©« processed г¦Ґ бгйҐбвўгҐв.

# %%
# Checkpoint of first data preparation stage
with open("./processed/clean_0.csv", "wb") as fd:
    pickle.dump(complaints, fd)

# %%
# Save each row text words count (messy splitted, not tokens)
words_statistic = []
for i in tqdm(complaints['narrative'].iloc):
    words_statistic.append(len(i.split()))
words_statistic = np.array(words_statistic)
# Out:
# 1266067it [00:14, 89328.32it/s]

# %%
print("The average number of words in a document is: {}.".format(np.mean(words_statistic)))
print("The minimum number of words in a document is: {}.".format(min(words_statistic)))
print("The maximum number of words in a document is: {}.".format(max(words_statistic)))
print("Lower then 5 words documents: {}".format(sum(words_statistic <= 5)))
# Out:
# The average number of words in a document is: 185.85345483295907.
# The minimum number of words in a document is: 1.
# The maximum number of words in a document is: 6314.
# Lower then 5 words documents: 2784

# %%
# Distribution graph
fig, ax = plt.subplots(figsize=(15,6))
ax.set_title("Distribution of number of words", fontsize=16)
ax.set_xlabel("Number of words")
ax.set_xticks(range(0, 6001, 500))
sns.histplot(words_statistic, bins=50, ax=ax, kde=True)
# Out:
# <Axes: title={'center': 'Distribution of number of words'}, xlabel='Number of words', ylabel='Count'>

# %%
pivot_data = complaints.copy()
pivot_data["words_cnt"] = words_statistic
pd.pivot_table(pivot_data, values="words_cnt", index=['Product'], aggfunc={'words_cnt': [np.mean, min, max,np.std]})
# Out:
#                                                      max        mean  min
# Product
# Bank account or service                             1284  229.883440    1  \
# Checking or savings account                         6014  236.111851    1
# Consumer Loan                                        845  207.503065    3
# Credit card                                          831  207.657713    2
# Credit card or prepaid card                         5735  228.860958    1
# Credit reporting                                     840  134.935100    2
# Credit reporting, credit repair services, or ot...  6024  153.611312    1
# Debt collection                                     6095  172.492682    1
# Money transfer, virtual currency, or money service  5988  223.462836    1
# Money transfers                                      771  214.019372    8
# Mortgage                                            5882  297.134038    1
# Other financial service                              735  229.061644   20
# Payday loan                                          803  141.961627    5
# Payday loan, title loan, or personal loan           4096  211.927988    1
# Prepaid card                                         791  182.132414    4
# Student loan                                        5421  232.668850    1
# Vehicle loan or lease                               6314  246.703241    1
# Virtual currency                                     658  166.500000   19
#
#                                                            std
# Product
# Bank account or service                             176.696177
# Checking or savings account                         256.400857
# Consumer Loan                                       170.642189
# Credit card                                         164.604975
# Credit card or prepaid card                         233.655330
# Credit reporting                                    129.307562
# Credit reporting, credit repair services, or ot...  195.195411
# Debt collection                                     220.620621
# Money transfer, virtual currency, or money service  260.483917
# Money transfers                                     170.367169
# Mortgage                                            303.434960
# Other financial service                             173.149349
# Payday loan                                         126.131628
# Payday loan, title loan, or personal loan           228.781613
# Prepaid card                                        156.770774
# Student loan                                        226.738703
# Vehicle loan or lease                               282.427429
# Virtual currency                                    190.898228

# %% [markdown]
# This table visualize mean/max/min/std for each class (product). Here we can see that there is a normal mean words for each class in document

# %%
# Clear ram

gc.collect()
del pivot_data
del words_statistic
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[98], line 4
#       1 # Clear ram
#       3 gc.collect()
# ----> 4 del pivot_data
#       5 del words_statistic
#       6 gc.collect()
#
# NameError: name 'pivot_data' is not defined

# %%
# !pip install pyspellchecker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.7.1-py3-none-any.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.7.1
# [notice] A new release of pip available: 22.2.2 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
stop_words = stopwords.words('english')
stop_words.extend(["xxxx", "xxx", "xxxxxxxx", "xx"]) # placeholders for names and other sensetive info
spell = SpellChecker()
wordnet_lemmatizer = WordNetLemmatizer()
punct_tokenizer = RegexpTokenizer(r"\w+")

def spell_correct(text_tokens):
    return [spell.correction(word) for word in text_tokens]

def preprocess_text(text: str):
    # Mutable function
    text = text.lower() # all text to lower case
    text = " ".join(text.split()) # remove extra spaces
    text_tokens = word_tokenize(text) # tokenize
    text_tmp = " ".join(text_tokens)
    text_tmp = re.sub(r'\d+', '', text_tmp) # remove numbers
    text_tokens = punct_tokenizer.tokenize(text_tmp) # remove punct
    text_tokens = [wordnet_lemmatizer.lemmatize(text_t) for text_t in text_tokens if text_t not in stop_words] # remove stop words and lematize them
    #text = spell_correct(text_tokens) # fix spell errors
    return text_tokens

# Example work
_ = preprocess_text(complaints.iloc[0].narrative)

# %%
complaints["tokens"] = complaints["narrative"].parallel_apply(preprocess_text)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=158259), Label(value='0 / 158259')…
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Program Files\Python310\lib\multiprocessing\pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Program Files\Python310\lib\multiprocessing\pool.py", line 51, in starmapstar
#     return list(itertools.starmap(args[0], args[1]))
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandarallel\core.py", line 158, in __call__
#     results = self.work_function(
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandarallel\data_types\series.py", line 26, in work
#     return data.apply(
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandas\core\series.py", line 4631, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py", line 1025, in apply
#     return self.apply_standard()
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandas\core\apply.py", line 1076, in apply_standard
#     mapped = lib.map_infer(
#   File "pandas\_libs\lib.pyx", line 2834, in pandas._libs.lib.map_infer
#   File "C:\Users\USER_ELISEY\AppData\Roaming\Python\Python310\site-packages\pandarallel\progress_bars.py", line 214, in closure
#     return user_defined_function(
#   File "C:\Users\USER_ELISEY\AppData\Local\Temp\ipykernel_17880\967519159.py", line 14, in preprocess_text
# NameError: name 'word_tokenize' is not defined
# """
#
# The above exception was the direct cause of the following exception:
#
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 complaints["tokens"] = complaints["narrative"].parallel_apply(preprocess_text)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandarallel\core.py:444, in parallelize_with_pipe.<locals>.closure(data, user_defined_function, *user_defined_function_args, **user_defined_function_kwargs)
#     441     elif worker_status == WorkerStatus.Error:
#     442         progress_bars.set_error(worker_index)
# --> 444 results = results_promise.get()
#     446 return data_type.reduce(results, reduce_extra)
#
# File C:\Program Files\Python310\lib\multiprocessing\pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# NameError: name 'word_tokenize' is not defined

# %%
# Multiprocessing apply with dask backends
complaints["tokens"] = complaints['narrative'].swifter.progress_bar(True).apply(lambda x: preprocess_text(x))
#complaints['narrative'].progress_apply(lambda x: x.split())
# Out:
# Dask Apply:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
complaints.head(5)
# Out:
#                                               Product
# 2                                            Mortgage  \
# 9   Credit reporting, credit repair services, or o...
# 13  Credit reporting, credit repair services, or o...
# 15  Credit reporting, credit repair services, or o...
# 24                                    Debt collection
#
#                                             narrative  Complaint ID  class
# 2   This complaint/letter serves as an appeal of t...       4729864     10  \
# 9   Accounts added and/or created unbeknownst to m...       4065272      6
# 13  I had a ccj which was paid within a month of t...       4034581      6
# 15  After sending multiple disputes to Equifax, Th...       4023957      6
# 24  XXXX direct marketing is a very old debt that ...       3909146      7
#
#                                                tokens
# 2   [complaint, letter, serf, appeal, denial, flag...
# 9   [account, added, created, unbeknownst, notice,...
# 13  [ccj, paid, within, month, judgment, one, remo...
# 15  [sending, multiple, dispute, equifax, sending,...
# 24  [direct, marketing, old, debt, keep, selling, ...

# %% [markdown]
# Find ngrams

# %%
# Checkpoint of second stage: clean tokens
with open("./processed/tokenized_1.csv", "wb") as fd:
    pickle.dump(complaints, fd)

# %%
stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='lemonchiffon',
                          stopwords=stopwords,
                          max_words=40,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(complaints['tokens']))

fig = plt.figure(figsize=(10,7))
plt.title("Wordcloud: top 40")
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %% [markdown]
# Show top 40 words from keywords

# %%
with open("./processed/tokenized_1.csv", "rb") as fd:
    complaints = pickle.load(fd)

# %%
def kw_extract_parallel(text):
    import yake
    return yake.KeywordExtractor(lan="en", n=3, dedupLim=0.4, top=4, features=None).extract_keywords(" ".join(text))

# %%
complaints["key_words"] = complaints["tokens"].parallel_apply(kw_extract_parallel)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=158259), Label(value='0 / 158259')…

# %%
complaints
# Out:
#                                                    Product
# 2                                                 Mortgage  \
# 9        Credit reporting, credit repair services, or o...
# 13       Credit reporting, credit repair services, or o...
# 15       Credit reporting, credit repair services, or o...
# 24                                         Debt collection
# ...                                                    ...
# 3515265                                           Mortgage
# 3515309                                           Mortgage
# 3515337                                           Mortgage
# 3515338                            Bank account or service
# 3515339                                   Credit reporting
#
#                                                  narrative  Complaint ID
# 2        This complaint/letter serves as an appeal of t...       4729864  \
# 9        Accounts added and/or created unbeknownst to m...       4065272
# 13       I had a ccj which was paid within a month of t...       4034581
# 15       After sending multiple disputes to Equifax, Th...       4023957
# 24       XXXX direct marketing is a very old debt that ...       3909146
# ...                                                    ...           ...
# 3515265  Can you let me know why after i paid my $ XXXX...       5616076
# 3515309  On XX/XX/XXXX Tuesday, after I switched my cho...       5307930
# 3515337  After falling behind on our mortgage in 2011, ...       2018364
# 3515338  Hello, I opened a CitiGold checking account wi...       2009169
# 3515339  I am unable to access my credit report online ...       2351504
#
#          class                                             tokens
# 2           10  [complaint, letter, serf, appeal, denial, flag...  \
# 9            6  [account, added, created, unbeknownst, notice,...
# 13           6  [ccj, paid, within, month, judgment, one, remo...
# 15           6  [sending, multiple, dispute, equifax, sending,...
# 24           7  [direct, marketing, old, debt, keep, selling, ...
# ...        ...                                                ...
# 3515265     10  [let, know, paid, payment, signed, loan, paper...
# 3515309     10  [tuesday, switched, choice, another, mortgage,...
# 3515337     10  [falling, behind, mortgage, husband, forced, f...
# 3515338      0  [hello, opened, citigold, checking, account, c...
# 3515339      5  [unable, access, credit, report, online, direc...
#
#                                                  key_words
# 2        [(covid refund modification, 3.420231987886078...
# 9        [(physically verifiable document, 6.7798600228...
# 13       [(removed credit file, 0.016559150827736194), ...
# 15       [(perform proper investigation, 0.001819008973...
# 24       [(removed phone avail, 0.002145023814281966), ...
# ...                                                    ...
# 3515265  [(wire title company, 6.0507263836354235e-05),...
# 3515309  [(cancel impound account, 3.418859216410219e-0...
# 3515337  [(husband forced file, 0.00692594101704979), (...
# 3515338  [(response promotional offer, 0.00281801525382...
# 3515339  [(unable access report, 0.0008315143765154092)...
#
# [1266067 rows x 6 columns]

# %%
# kw_extractor = yake.KeywordExtractor()
# language = "en"
# dedup_threshhold = 0.4
# numOfKeywords = 4
# # Init extractors
# extractor_n_1 = yake.KeywordExtractor(lan=language, n=1, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
# extractor_n_2 = yake.KeywordExtractor(lan=language, n=2, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
# extractor_n_3 = yake.KeywordExtractor(lan=language, n=3, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
# # summary is 9 key phrases(3 per each extractor)
# #print(extractor_n_3.extract_keywords(" ".join(complaints.iloc[0].tokens)))

# #def extract_key(text):
# #    keywords = extractor.extract_keywords(text)
# #    return [i[0] for i in keywords]

# #complaints["key_words"] = complaints["narrative"].swifter.progress_bar(True).apply(lambda x: [i[0] for i in extractor_n_3.extract_keywords(" ".join(x))])
# complaints["key_words"] = complaints["tokens"].swifter.progress_bar(True).allow_dask_on_strings(True).force_parallel(True).apply(lambda x: [i[0] for i in extractor_n_3.extract_keywords(" ".join(x))])
# Out:
# Dask Apply:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
# keybert
from keybert import KeyBERT

kw_model = KeyBERT()
  keywords = kw_model.extract_keywords('''Supervised learning is the machine learning task of learning a function that
         maps an input to an output based on example input-output pairs. It infers a
         function from labeled training data consisting of a set of training examples.
         In supervised learning, each example is a pair consisting of an input object
         (typically a vector) and a desired output value (also called the supervisory signal).
         A supervised learning algorithm analyzes the training data and produces an inferred function,
         which can be used for mapping new examples. An optimal scenario will allow for the
         algorithm to correctly determine the class labels for unseen instances. This requires
         the learning algorithm to generalize from the training data to unseen situations in a
         'reasonable' way (see inductive bias).
  ''', keyphrase_ngram_range=(1, 3))
