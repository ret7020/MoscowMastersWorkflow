# %%
# !wget https://files.consumerfinance.gov/ccdb/complaints.csv.zip
# Out:
# --2023-04-09 14:03:12--  https://files.consumerfinance.gov/ccdb/complaints.csv.zip
# Resolving files.consumerfinance.gov (files.consumerfinance.gov)... 13.249.85.127, 13.249.85.25, 13.249.85.59, ...
# Connecting to files.consumerfinance.gov (files.consumerfinance.gov)|13.249.85.127|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 558486104 (533M) [binary/octet-stream]
# Saving to: ‘complaints.csv.zip’
#
# complaints.csv.zip  100%[===================>] 532.61M  64.6MB/s    in 11s
#
# 2023-04-09 14:03:23 (46.6 MB/s) - ‘complaints.csv.zip’ saved [558486104/558486104]

# %%
# !unzip complaints.csv.zip
# Out:
# Archive:  complaints.csv.zip
#   inflating: complaints.csv

# %%
# !rm complaints.csv.zip

# %%
# !pip3 install catboost yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting catboost
#   Downloading catboost-1.1.1-cp39-none-manylinux1_x86_64.whl (76.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.6/76.6 MB 12.7 MB/s eta 0:00:00
# Collecting yake
#   Downloading yake-0.4.8-py2.py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 KB 11.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from catboost) (1.10.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.22.4)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.9/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.9/dist-packages (from catboost) (5.13.1)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/dist-packages (from catboost) (1.4.4)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from catboost) (1.16.0)
# Collecting jellyfish
#   Downloading jellyfish-0.11.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 52.4 MB/s eta 0:00:00
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.9/dist-packages (from yake) (8.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from yake) (3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from yake) (0.8.10)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (23.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (8.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (5.12.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly->catboost) (8.2.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from segtok->yake) (2022.10.31)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->catboost) (3.15.0)
# Installing collected packages: segtok, jellyfish, yake, catboost
# Successfully installed catboost-1.1.1 jellyfish-0.11.2 segtok-1.5.11 yake-0.4.8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import catboost as cb
import tqdm

# %%
complaints = pd.read_csv("complaints.csv")
# Out:
# <ipython-input-2-8412033e1494>:1: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   complaints = pd.read_csv("complaints.csv")

# %%
complaints.head(10)
# Out:
#   Date received                                            Product  \
# 0    2022-03-10  Credit reporting, credit repair services, or o...
# 1    2022-01-26  Credit reporting, credit repair services, or o...
# 2    2021-09-17                                           Mortgage
# 3    2021-08-02  Credit reporting, credit repair services, or o...
# 4    2021-05-17  Credit reporting, credit repair services, or o...
# 5    2021-03-12  Money transfer, virtual currency, or money ser...
# 6    2021-01-21                                    Debt collection
# 7    2021-01-20  Credit reporting, credit repair services, or o...
# 8    2021-01-14  Credit reporting, credit repair services, or o...
# 9    2021-01-13  Credit reporting, credit repair services, or o...
#
#                 Sub-product  \
# 0          Credit reporting
# 1          Credit reporting
# 2               VA mortgage
# 3          Credit reporting
# 4          Credit reporting
# 5  Mobile or digital wallet
# 6                Other debt
# 7          Credit reporting
# 8          Credit reporting
# 9          Credit reporting
#
#                                                Issue  \
# 0                        Improper use of your report
# 1               Incorrect information on your report
# 2                         Struggling to pay mortgage
# 3  Problem with a credit reporting company's inve...
# 4               Incorrect information on your report
# 5  Managing, opening, or closing your mobile wall...
# 6                    Written notification about debt
# 7  Problem with a credit reporting company's inve...
# 8               Incorrect information on your report
# 9               Incorrect information on your report
#
#                                            Sub-issue  \
# 0      Reporting company used your report improperly
# 1                Information belongs to someone else
# 2                                                NaN
# 3  Was not notified of investigation status or re...
# 4                Information belongs to someone else
# 5                                                NaN
# 6   Didn't receive enough information to verify debt
# 7  Their investigation did not fix an error on yo...
# 8                Information belongs to someone else
# 9                Information belongs to someone else
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1                                                NaN
# 2  This complaint/letter serves as an appeal of t...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Accounts added and/or created unbeknownst to m...
#
#                              Company public response  \
# 0  Company has responded to the consumer and the ...
# 1  Company has responded to the consumer and the ...
# 2  Company has responded to the consumer and the ...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  Company has responded to the consumer and the ...
# 8                                                NaN
# 9                                                NaN
#
#                                   Company State ZIP code           Tags  \
# 0     Experian Information Solutions Inc.    CA  92394.0            NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    VA  20166.0            NaN
# 2                     Flagstar Bank, N.A.    CA  91384.0  Servicemember
# 3                           EQUIFAX, INC.    FL  33147.0            NaN
# 4                           EQUIFAX, INC.    PA  19124.0            NaN
# 5                    Paypal Holdings, Inc   NaN      NaN            NaN
# 6                      EOS Holdings, Inc.    NY  11550.0            NaN
# 7                          CITIBANK, N.A.    NY  10560.0            NaN
# 8                           EQUIFAX, INC.    PA  19027.0            NaN
# 9                           EQUIFAX, INC.    FL  33325.0            NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN         Phone           2022-03-10
# 1       Consent not provided           Web           2022-01-26
# 2           Consent provided           Web           2021-09-17
# 3       Consent not provided           Web           2021-08-02
# 4       Consent not provided           Web           2021-05-17
# 5       Consent not provided           Web           2021-03-12
# 6       Consent not provided           Web           2021-01-21
# 7       Consent not provided           Web           2021-01-20
# 8       Consent not provided           Web           2021-01-14
# 9           Consent provided           Web           2021-01-13
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 1      Closed with explanation              Yes                NaN
# 2      Closed with explanation              Yes                NaN
# 3      Closed with explanation              Yes                NaN
# 4      Closed with explanation              Yes                NaN
# 5      Closed with explanation              Yes                NaN
# 6      Closed with explanation              Yes                NaN
# 7      Closed with explanation              Yes                NaN
# 8      Closed with explanation              Yes                NaN
# 9      Closed with explanation              Yes                NaN
#
#    Complaint ID
# 0       5308860
# 1       5152476
# 2       4729864
# 3       4596161
# 4       4384343
# 5       4207043
# 6       4082932
# 7       4081186
# 8       4067247
# 9       4065272

# %%
complaints = complaints.drop(["Date received", "Sub-product", "Issue", "Sub-issue", "Company public response", "Company", "State", "ZIP code", "Tags", "Consumer consent provided?", "Submitted via", "Date sent to company", "Company response to consumer", "Timely response?", "Consumer disputed?"], axis=1)

# %%
complaints
# Out:
#                                                    Product  \
# 0        Credit reporting, credit repair services, or o...
# 1        Credit reporting, credit repair services, or o...
# 2                                                 Mortgage
# 3        Credit reporting, credit repair services, or o...
# 4        Credit reporting, credit repair services, or o...
# ...                                                    ...
# 3515338                            Bank account or service
# 3515339                                   Credit reporting
# 3515340                                           Mortgage
# 3515341                                           Mortgage
# 3515342  Credit reporting, credit repair services, or o...
#
#                               Consumer complaint narrative  Complaint ID
# 0                                                      NaN       5308860
# 1                                                      NaN       5152476
# 2        This complaint/letter serves as an appeal of t...       4729864
# 3                                                      NaN       4596161
# 4                                                      NaN       4384343
# ...                                                    ...           ...
# 3515338  Hello, I opened a CitiGold checking account wi...       2009169
# 3515339  I am unable to access my credit report online ...       2351504
# 3515340                                                NaN       2467475
# 3515341                                                NaN       2333389
# 3515342                                                NaN       2846995
#
# [3515343 rows x 3 columns]

# %%
complaints = complaints.dropna()

# %%
complaints = complaints.rename(columns={"Consumer complaint narrative": "narrative"})

# %%
complaints.groupby('Product').count().plot(kind='bar')
# Out:
# <Axes: xlabel='Product'>

# %%
dt = []
for i in tqdm.tqdm(complaints['narrative'].iloc):
  dt.append(len(i.split()))
dt = np.array(dt)
# Out:
# 1266067it [00:17, 70546.77it/s]

# %%
dt
# Out:
# array([1817, 1291,   23, ...,   73,  194,  200])

# %%
print("The average number of words in a document is: {}.".format(np.mean(dt)))
print("The minimum number of words in a document is: {}.".format(min(dt)))
print("The maximum number of words in a document is: {}.".format(max(dt)))
print("Lower then 5 words documents: {}".format(sum(dt <= 5)))
# Out:
# The average number of words in a document is: 185.85345483295907.
# The minimum number of words in a document is: 1.
# The maximum number of words in a document is: 6314.
# Lower then 5 words documents: 2784

# %%
# Distribution graph
fig, ax = plt.subplots(figsize=(15,6))
ax.set_title("Distribution of number of words", fontsize=16)
ax.set_xlabel("Number of words")
sns.distplot(dt, bins=50, ax=ax)
# Out:
# <ipython-input-12-8a30a99abbcf>:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dt, bins=50, ax=ax)
# <Axes: title={'center': 'Distribution of number of words'}, xlabel='Number of words', ylabel='Density'>

# %%
pivot_data = complaints.copy()
pivot_data["words_cnt"] = dt

# %%
pivot_data.head(2)
# Out:
#                                              Product  \
# 2                                           Mortgage
# 9  Credit reporting, credit repair services, or o...
#
#                                            narrative  Complaint ID  words_cnt
# 2  This complaint/letter serves as an appeal of t...       4729864       1817
# 9  Accounts added and/or created unbeknownst to m...       4065272       1291

# %%
pd.pivot_table(pivot_data, values="words_cnt", index=['Product'], aggfunc={'words_cnt': [np.mean, min, max,np.std]})
# Out:
#                                                      max        mean  min  \
# Product
# Bank account or service                             1284  229.883440    1
# Checking or savings account                         6014  236.111851    1
# Consumer Loan                                        845  207.503065    3
# Credit card                                          831  207.657713    2
# Credit card or prepaid card                         5735  228.860958    1
# Credit reporting                                     840  134.935100    2
# Credit reporting, credit repair services, or ot...  6024  153.611312    1
# Debt collection                                     6095  172.492682    1
# Money transfer, virtual currency, or money service  5988  223.462836    1
# Money transfers                                      771  214.019372    8
# Mortgage                                            5882  297.134038    1
# Other financial service                              735  229.061644   20
# Payday loan                                          803  141.961627    5
# Payday loan, title loan, or personal loan           4096  211.927988    1
# Prepaid card                                         791  182.132414    4
# Student loan                                        5421  232.668850    1
# Vehicle loan or lease                               6314  246.703241    1
# Virtual currency                                     658  166.500000   19
#
#                                                            std
# Product
# Bank account or service                             176.696177
# Checking or savings account                         256.400857
# Consumer Loan                                       170.642189
# Credit card                                         164.604975
# Credit card or prepaid card                         233.655330
# Credit reporting                                    129.307562
# Credit reporting, credit repair services, or ot...  195.195411
# Debt collection                                     220.620621
# Money transfer, virtual currency, or money service  260.483917
# Money transfers                                     170.367169
# Mortgage                                            303.434960
# Other financial service                             173.149349
# Payday loan                                         126.131628
# Payday loan, title loan, or personal loan           228.781613
# Prepaid card                                        156.770774
# Student loan                                        226.738703
# Vehicle loan or lease                               282.427429
# Virtual currency                                    190.898228

# %%
reset_selective -f dt comp1_dist pivot_data

# %%
# Release memory
import gc

gc.collect()

del comp1_dist
del pivot_data
del dt
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-f591f3f5538c> in <cell line: 8>()
#       6 del comp1_dist
#       7 del pivot_data
# ----> 8 del dt
#       9 gc.collect()
#
# NameError: name 'dt' is not defined

# %%
# TODO BUILD GRAPH of words mean/avgs from table above

# %%
# !pip3 install pandarallel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandarallel
#   Downloading pandarallel-1.6.4.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting dill>=0.3.1
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 KB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1 in /usr/local/lib/python3.9/dist-packages (from pandarallel) (1.4.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.9/dist-packages (from pandarallel) (5.9.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1->pandarallel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1->pandarallel) (2022.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas>=1->pandarallel) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1->pandarallel) (1.16.0)
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.4-py3-none-any.whl size=16677 sha256=8ef36c74153d396c22fc6e4113a9238c84c8ce86d5954422e1f41d45ffc8a851
#   Stored in directory: /root/.cache/pip/wheels/41/01/29/deaa71fe596f8d857e57c4fb388db8861e23e6ed0b03204dcb
# Successfully built pandarallel
# Installing collected packages: dill, pandarallel
# Successfully installed dill-0.3.6 pandarallel-1.6.4

# %%
complaints.iloc[0].narrative
# Out:
# 'This complaint/letter serves as an appeal of the denial by Flagstar bank of our application for loss mitigation. Although we have been supplied insufficient information to provide a complete appeal, this letter serves as our best effort given the current situation. We submitted 43 pages of documentation in our loss mitigation application, beginning on XX/XX/XXXX. This process took hours of work, and multiple phone calls to the Flagstar customer support/hardship task force line to work this process out. The online application was incorrectly entering a date, so we were instructed to print and manually file the paperwork, then upload it to the portal which we did. I called to follow up, and was notified at that time verbally ( Friday XX/XX/XXXX ) that more documentation was needed. We completed this other documentation and uploaded on the portal Saturday XX/XX/XXXX. \n\nOn Tuesday XX/XX/XXXX I again called to validate that all documentation was received and was in proper order. It was at this time that I was notified that our application had been denied, and informed that I had the option to appeal. I requested the reason for denial and was told VA has denied you because you did not make 12 payments. I requested the documentation of the denial so that I could form my appeal. The agent told me it would be in the mail, but that I needed to be quick because I only had 14 days to appeal. I requested escalation to a manager/supervisor and was told someone would call me back within 24-48 hours. \n\nThe following morning ( Wednesday XX/XX/XXXX ) I received a call from XXXX, an escalation manager by his description. XXXX was short and confrontational from the start of our conversation, and I became upset. I specifically asked for clarification about what options are available to us as VA loan holders, because VA has provided specific guidance for new programs specific to the COVID 19 situation, to support veterans retaining their home and coming out of forbearance successfully. By this time, I had researched VA loan seasoning requirements and found out that VA does not require 12 months of payments, but only 6 months of payments + 210 days elapsed since the first payment of the loan ( see references VA XXXX XXXX0-25 & 26/20/25 Change 1, as well as Public Law NO : 116-33, related to Senate Bill 1749 Protecting Affordable Mortages for Veterans Act of 2019. ) We did make 7 full payments on XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX, XX/XX/XXXX to our previous servicer, XXXX XXXX, before electing COVID 19 Forbearance due to my wife not being able to work as an elementary school teacher due to the requirement that our school age children be at home. \n\nI requested XXXX to provide me in writing the reasons for denial, and he said XXXX would not be doing that. I asked how I could appeal, without seeing the denial reasoning in writing, and he repeatedly refused to assist. He repeatedly stated that VA had been the party to deny me on the application, and this is either an outright lie or misdirection, as VA circular 26-21-13 ( the COVID-19 Home Retention Waterfall and COVID-19 Refund Modification ) clearly states in the circular that VA prior approval for multiple programs ( including the new VAPCP and COVID-19 Refund Modification ) is not required. Flagstar stating both that VA issued the denial and that the reasoning is that the loan is not-seasoned by failing to complete 12 payments is clearly at error.\n\nThrough all of this time, I have been told repeated that information regarding our appeal has been mailed to us, but not one piece of mail has been received regarding this application. I finally got transferred to Flagstar customer support team, where after 50 minutes on hold I received a pdf document by email from customer support agent XXXX XXXX. This document includes 88 total pages, including our full Loss Mitigation App, the full credit reports for both myself and my wife, and only 3 pages of an obviously  ...

# %%
import re
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords

stop = stopwords.words('english')
stop.extend(["xxxx", "xx", "xxxxx", "x" * 8])


def preprocess_text(text: str) -> str:
  text = text.lower() # lower
  text = re.sub(r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", text) # Remove urls, punct and spec symbols
  text = " ".join([word for word in text.split() if word not in (stop)]) # remove stop words

  return text
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from tqdm import tqdm

tqdm.pandas()
complaints["narrative"] = complaints["narrative"].progress_apply(lambda x: preprocess_text(x))
# Out:
# 100%|██████████| 1266067/1266067 [06:42<00:00, 3143.47it/s]

# %%
complaints.head(5)
# Out:
#                                               Product  \
# 2                                            Mortgage
# 9   Credit reporting, credit repair services, or o...
# 13  Credit reporting, credit repair services, or o...
# 15  Credit reporting, credit repair services, or o...
# 24                                    Debt collection
#
#                                             narrative  Complaint ID
# 2   complaintletter serves appeal denial flagstar ...       4729864
# 9   accounts added andor created unbeknownst notic...       4065272
# 13  ccj paid within month judgment one removed cre...       4034581
# 15  sending multiple disputes equifax sending repl...       4023957
# 24  direct marketing old debt keeps selling inform...       3909146

# %%
# !pip3 install wordcloud
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.9/dist-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from wordcloud) (1.22.4)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from wordcloud) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (4.39.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->wordcloud) (5.12.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->wordcloud) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud, STOPWORDS

stopwords = set(STOPWORDS)
wordcloud = WordCloud(
                          background_color='lemonchiffon',
                          stopwords=stopwords,
                          max_words=40,
                          max_font_size=40, 
                          random_state=42
                         ).generate(str(complaints['processed']))

fig = plt.figure(figsize=(10,7))
plt.title("Wordcloud: top 40")
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
# !pip3 install yake
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: yake in /usr/local/lib/python3.9/dist-packages (0.4.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from yake) (1.22.4)
# Requirement already satisfied: segtok in /usr/local/lib/python3.9/dist-packages (from yake) (1.5.11)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.9/dist-packages (from yake) (0.11.2)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.9/dist-packages (from yake) (8.1.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from yake) (0.8.10)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from yake) (3.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.9/dist-packages (from segtok->yake) (2022.10.31)

# %%
import yake

kw_extractor = yake.KeywordExtractor()

language = "en"
max_ngram_size = 3
dedup_threshhold = 0.9
numOfKeywords = 3
extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
def extract_keyw(text):
  keywords = extractor.extract_keywords(text)
  return [i[0] for i in keywords]

complaints["key_words"] = complaints["processed"].progress_apply(lambda x: extract_keyw(x))
# Out:
#   0%|          | 253/1266067 [00:03<4:57:53, 70.82it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-8b9cff4f6004> in <cell line: 14>()
#      12   return [i[0] for i in keywords]
#      13
# ---> 14 complaints["key_words"] = complaints["processed"].progress_apply(lambda x: extract_keyw(x))
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     803                 # on the df using our wrapper (which provides bar updating)
#     804                 try:
# --> 805                     return getattr(df, df_function)(wrapper, **kwargs)
#     806                 finally:
#     807                     t.close()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     798                     # take a fast or slow code path; so stop when t.total==t.n
#     799                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800                     return func(*args, **kwargs)
#     801
#     802                 # Apply the provided function (in **kwargs)
#
# <ipython-input-75-8b9cff4f6004> in <lambda>(x)
#      12   return [i[0] for i in keywords]
#      13
# ---> 14 complaints["key_words"] = complaints["processed"].progress_apply(lambda x: extract_keyw(x))
#
# <ipython-input-75-8b9cff4f6004> in extract_keyw(text)
#       9 extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
#      10 def extract_keyw(text):
# ---> 11   keywords = extractor.extract_keywords(text)
#      12   return [i[0] for i in keywords]
#      13
#
# /usr/local/lib/python3.9/dist-packages/yake/yake.py in extract_keywords(self, text)
#      63             text = text.replace('\n\t',' ')
#      64             dc = DataCore(text=text, stopword_set=self.stopword_set, windowsSize=self.windowsSize, n=self.n)
# ---> 65             dc.build_single_terms_features(features=self.features)
#      66             dc.build_mult_terms_features(features=self.features)
#      67             resultSet = []
#
# /usr/local/lib/python3.9/dist-packages/yake/datarepresentation.py in build_single_terms_features(self, features)
#     111         stdTF = validTFs.std()
#     112         maxTF = max([ x.tf for x in self.terms.values()])
# --> 113         list(map(lambda x: x.updateH(maxTF=maxTF, avgTF=avgTF, stdTF=stdTF, number_of_sentences=self.number_of_sentences, features=features), self.terms.values()))
#     114
#     115     def build_mult_terms_features(self, features=None):
#
# /usr/local/lib/python3.9/dist-packages/yake/datarepresentation.py in <lambda>(x)
#     111         stdTF = validTFs.std()
#     112         maxTF = max([ x.tf for x in self.terms.values()])
# --> 113         list(map(lambda x: x.updateH(maxTF=maxTF, avgTF=avgTF, stdTF=stdTF, number_of_sentences=self.number_of_sentences, features=features), self.terms.values()))
#     114
#     115     def build_mult_terms_features(self, features=None):
#
# /usr/local/lib/python3.9/dist-packages/yake/datarepresentation.py in updateH(self, maxTF, avgTF, stdTF, number_of_sentences, features)
#     378
#     379         if features == None or "WPos" in features:
# --> 380             self.WPos = math.log( math.log( 3. + np.median(list(self.occurs.keys())) ) )
#     381
#     382         self.H = (self.WPos * self.WRel) / (self.WCase + (self.WFreq / self.WRel) + (self.WSpread / self.WRel))
#
# /usr/local/lib/python3.9/dist-packages/numpy/core/overrides.py in median(*args, **kwargs)
#
# /usr/local/lib/python3.9/dist-packages/numpy/lib/function_base.py in median(a, axis, out, overwrite_input, keepdims)
#    3791
#    3792     """
# -> 3793     r, k = _ureduce(a, func=_median, axis=axis, out=out,
#    3794                     overwrite_input=overwrite_input)
#    3795     if keepdims:
#
# /usr/local/lib/python3.9/dist-packages/numpy/lib/function_base.py in _ureduce(a, func, **kwargs)
#    3675
#    3676     """
# -> 3677     a = np.asanyarray(a)
#    3678     axis = kwargs.get('axis', None)
#    3679     if axis is not None:
#
# KeyboardInterrupt:

# %%
# %%time
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer
from sklearn.decomposition import NMF

tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')
dtm = tfidf.fit_transform(complaints['narrative'])
# Out:
# CPU times: user 1min 24s, sys: 2.14 s, total: 1min 27s
# Wall time: 1min 33s

# %%
# Find best topics number

from gensim.corpora.dictionary import Dictionary
from gensim.models.nmf import Nmf
from gensim.models.coherencemodel import CoherenceModel
from operator import itemgetter


texts = complaints['narrative']
dataset = [d.split() for d in texts]

# Create a dictionary
# In gensim a dictionary is a mapping between words and their integer id
dictionary = Dictionary(dataset)

# Filter out extremes to limit the number of features
dictionary.filter_extremes(
    no_below=3,
    no_above=0.85,
    keep_n=5000
)

# Create the bag-of-words format (list of (token_id, token_count))
corpus = [dictionary.doc2bow(text) for text in dataset]

# Create a list of the topic numbers we want to try
topic_nums = list(np.arange(5, 10, 1))

# Run the nmf model and calculate the coherence score
# for each number of topics
coherence_scores = []

for num in topic_nums:
    nmf = Nmf(
        corpus=corpus,
        num_topics=num,
        id2word=dictionary,
        chunksize=2000,
        passes=5,
        kappa=.1,
        minimum_probability=0.01,
        w_max_iter=300,
        w_stop_condition=0.0001,
        h_max_iter=100,
        h_stop_condition=0.001,
        eval_every=10,
        normalize=True,
        random_state=42
    )
    
    # Run the coherence model to get the score
    cm = CoherenceModel(
        model=nmf,
        texts=texts,
        dictionary=dictionary,
        coherence='c_v'
    )
    
    coherence_scores.append(round(cm.get_coherence(), 5))

# Get the number of topics with the highest coherence score
scores = list(zip(topic_nums, coherence_scores))
best_num_topics = sorted(scores, key=itemgetter(1), reverse=True)[0][0]

print(best_num_topics)

# %%
import spacy

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=True)
tqdm.tqdm.pandas()


nlp = spacy.load("en_core_web_sm")
# Add custom stop words
for stop in ["XXX", "XX", "XXXX", "xxxx", "xxxxxxxx"]:
  nlp.Defaults.stop_words.add(stop)


def preprocess_text(complaints):
  print("Removing stop words, symbols and make lemmatization")
  #complaints["processed"] = complaints.narrative.parallel_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
  complaints['processed'] = complaints['narrative'].progress_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
preprocess_text(complaints)
# Out:
# INFO: Pandarallel will run on 1 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# Removing stop words, symbols and make lemmatization
#  11%|█         | 141392/1264742 [1:05:57<8:44:00, 35.73it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-d8ac79e6017c> in <cell line: 20>()
#      18   #complaints["processed"] = complaints.narrative.parallel_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
#      19   complaints['processed'] = complaints['narrative'].progress_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
# ---> 20 preprocess_text(complaints)
#
# <ipython-input-73-d8ac79e6017c> in preprocess_text(complaints)
#      17   print("Removing stop words, symbols and make lemmatization")
#      18   #complaints["processed"] = complaints.narrative.parallel_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
# ---> 19   complaints['processed'] = complaints['narrative'].progress_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
#      20 preprocess_text(complaints)
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in inner(df, func, *args, **kwargs)
#     803                 # on the df using our wrapper (which provides bar updating)
#     804                 try:
# --> 805                     return getattr(df, df_function)(wrapper, **kwargs)
#     806                 finally:
#     807                     t.close()
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4431         dtype: float64
#    4432         """
# -> 4433         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4434
#    4435     def _reduce(
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply(self)
#    1086             return self.apply_str()
#    1087
# -> 1088         return self.apply_standard()
#    1089
#    1090     def agg(self):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1141                 # List[Union[Callable[..., Any], str]]]]]"; expected
#    1142                 # "Callable[[Any], Any]"
# -> 1143                 mapped = lib.map_infer(
#    1144                     values,
#    1145                     f,  # type: ignore[arg-type]
#
# /usr/local/lib/python3.9/dist-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /usr/local/lib/python3.9/dist-packages/tqdm/std.py in wrapper(*args, **kwargs)
#     798                     # take a fast or slow code path; so stop when t.total==t.n
#     799                     t.update(n=1 if not t.total or t.n < t.total else 0)
# --> 800                     return func(*args, **kwargs)
#     801
#     802                 # Apply the provided function (in **kwargs)
#
# <ipython-input-73-d8ac79e6017c> in <lambda>(x)
#      17   print("Removing stop words, symbols and make lemmatization")
#      18   #complaints["processed"] = complaints.narrative.parallel_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
# ---> 19   complaints['processed'] = complaints['narrative'].progress_apply(lambda x: " ".join(token.lemma_ for token in nlp(x) if not token.is_stop and token.is_alpha))
#      20 preprocess_text(complaints)
#
# /usr/local/lib/python3.9/dist-packages/spacy/language.py in __call__(self, text, disable, component_cfg)
#     997         DOCS: https://spacy.io/api/language#call
#     998         """
# --> 999         doc = self._ensure_doc(text)
#    1000         if component_cfg is None:
#    1001             component_cfg = {}
#
# /usr/local/lib/python3.9/dist-packages/spacy/language.py in _ensure_doc(self, doc_like)
#    1088             return doc_like
#    1089         if isinstance(doc_like, str):
# -> 1090             return self.make_doc(doc_like)
#    1091         if isinstance(doc_like, bytes):
#    1092             return Doc(self.vocab).from_bytes(doc_like)
#
# /usr/local/lib/python3.9/dist-packages/spacy/language.py in make_doc(self, text)
#    1080                 Errors.E088.format(length=len(text), max_length=self.max_length)
#    1081             )
# -> 1082         return self.tokenizer(text)
#    1083
#    1084     def _ensure_doc(self, doc_like: Union[str, Doc, bytes]) -> Doc:
#
# KeyboardInterrupt:

# %%
complaints
# Out:
#                                                    Product  \
# 2                                                 Mortgage
# 7        Credit reporting, credit repair services, or o...
# 11       Credit reporting, credit repair services, or o...
# 17       Credit reporting, credit repair services, or o...
# 18                             Credit card or prepaid card
# ...                                                    ...
# 3511753                                           Mortgage
# 3511797                                           Mortgage
# 3511825                                           Mortgage
# 3511826                            Bank account or service
# 3511827                                   Credit reporting
#
#                                                  narrative  Complaint ID
# 2        This complaint/letter serves as an appeal of t...       4729864
# 7        I am XXXX XXXX XXXX and I am submitting this c...       4906602
# 11       in accordance with the Fair Credit Reporting a...       5274806
# 17       Unauthorized inquiries were discovered on my m...       5271604
# 18       I have a card through comenity bank. I think t...       5993564
# ...                                                    ...           ...
# 3511753  Can you let me know why after i paid my $ XXXX...       5616076
# 3511797  On XX/XX/XXXX Tuesday, after I switched my cho...       5307930
# 3511825  After falling behind on our mortgage in 2011, ...       2018364
# 3511826  Hello, I opened a CitiGold checking account wi...       2009169
# 3511827  I am unable to access my credit report online ...       2351504
#
# [1264742 rows x 3 columns]

# %%
from joblib import Parallel, delayed

def lemmatize_pipe(doc):
    lemma_list = [str(tok.lemma_).lower() for tok in doc
                  if tok.is_alpha and tok.text.lower() not in nlp.Defaults.stop_words] 
    return lemma_list

def preprocess_pipe(texts):
    preproc_pipe = []
    for doc in nlp.pipe(texts, batch_size=20):
        preproc_pipe.append(lemmatize_pipe(doc))
    return preproc_pipe



def chunker(iterable, total_length, chunksize):
    return (iterable[pos: pos + chunksize] for pos in range(0, total_length, chunksize))

def flatten(list_of_lists):
    "Flatten a list of lists to a combined list"
    return [item for sublist in list_of_lists for item in sublist]

def process_chunk(texts):
    preproc_pipe = []
    for doc in nlp.pipe(texts, batch_size=20):
        preproc_pipe.append(lemmatize_pipe(doc))
    return preproc_pipe

def preprocess_parallel(texts, chunksize=100):
    executor = Parallel(n_jobs=7, backend='multiprocessing', prefer="processes")
    do = delayed(process_chunk)
    tasks = (do(chunk) for chunk in chunker(texts, len(complaints), chunksize=chunksize))
    result = executor(tasks)
    return flatten(result)

# %%
# %%time
complaints['lem'] = preprocess_parallel(complaints['narrative'], chunksize=1000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-107-c193c34556c1> in preprocess_parallel(texts, chunksize)
#      31     do = delayed(process_chunk)
#      32     tasks = (do(chunk) for chunk in chunker(texts, len(complaints), chunksize=chunksize))
# ---> 33     result = executor(tasks)
#      34     return flatten(result)
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1059
#    1060             with self._backend.retrieval_context():
# -> 1061                 self.retrieve()
#    1062             # Make sure that we get a last message telling us we are done
#    1063             elapsed_time = time.time() - self._start_time
#
# /usr/local/lib/python3.9/dist-packages/joblib/parallel.py in retrieve(self)
#     936             try:
#     937                 if getattr(self._backend, 'supports_timeout', False):
# --> 938                     self._output.extend(job.get(timeout=self.timeout))
#     939                 else:
#     940                     self._output.extend(job.get())
#
# /usr/lib/python3.9/multiprocessing/pool.py in get(self, timeout)
#     763
#     764     def get(self, timeout=None):
# --> 765         self.wait(timeout)
#     766         if not self.ready():
#     767             raise TimeoutError
#
# /usr/lib/python3.9/multiprocessing/pool.py in wait(self, timeout)
#     760
#     761     def wait(self, timeout=None):
# --> 762         self._event.wait(timeout)
#     763
#     764     def get(self, timeout=None):
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     579             signaled = self._flag
#     580             if not signaled:
# --> 581                 signaled = self._cond.wait(timeout)
#     582             return signaled
#     583
#
# /usr/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
# !pip3 install yake

# %%
complaints.iloc[0]
# Out:
# Product                                                  Mortgage
# narrative       This complaint/letter serves as an appeal of t...
# Complaint ID                                              4729864
# Name: 2, dtype: object

# %%
import yake

kw_extractor = yake.KeywordExtractor()
language = "en"
max_ngram_size = 2
dedup_threshhold = 0.9
numOfKeywords = 5
extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=dedup_threshhold, top=numOfKeywords, features=None)
text = " ".join(token.lemma_ for token in nlp(complaints.iloc[0].narrative) if not token.is_stop and token.is_alpha)
keywords = extractor.extract_keywords(text)
print(keywords)
# Out:
# [('VAPCP Refund', 0.00017857670866535966), ('Flagstar bank', 0.00019363749789967893), ('Home Retention', 0.00021526622663790057), ('loss mitigation', 0.0002180538674508001), ('COVID VAPCP', 0.0002403162058323294)]

# %%
complaints.head()
# Out:
#                                               Product  \
# 2                                            Mortgage
# 7   Credit reporting, credit repair services, or o...
# 11  Credit reporting, credit repair services, or o...
# 17  Credit reporting, credit repair services, or o...
# 18                        Credit card or prepaid card
#
#                                             narrative  Complaint ID
# 2   This complaint/letter serves as an appeal of t...       4729864
# 7   I am XXXX XXXX XXXX and I am submitting this c...       4906602
# 11  in accordance with the Fair Credit Reporting a...       5274806
# 17  Unauthorized inquiries were discovered on my m...       5271604
# 18  I have a card through comenity bank. I think t...       5993564

# %%
complaints = complaints.drop("processed", axis=1)
